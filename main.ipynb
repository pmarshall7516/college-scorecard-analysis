# %% [markdown]
# Patrick Marshall and Patrick Rafferty
#
# Introduction to Data Science
#
# Final Project Notebook
#
# 7 March 2024

# %% [markdown]
# # Imports

# %%
import urllib.request
import zipfile

# Imports
import pandas as pd
from scipy import stats

# %% [markdown]
# # Data Loading

# %%
# Retrieve Data Zip File
if not zipfile.is_zipfile("data/CollegeScorecard_Raw_Data_09262023.zip"):
    urllib.request.urlretrieve("https://ed-public-download.app.cloud"
                               ".gov/downloads/CollegeScorecard_Raw_Data_09262023.zip",
                               "data/CollegeScorecard_Raw_Data_09262023.zip")

# %%
# Using Pandas' built-in zip support does not work since our zip file has more than one file 
# archived inside.
with zipfile.ZipFile("data/CollegeScorecard_Raw_Data_09262023.zip").open(
        "data/MERGED2021_22_PP.csv") as data_csv:
    college_scorecard_institution = pd.read_csv(data_csv, low_memory=False,
                                                na_values=("NULL", "PrivacySuppressed")).dropna(
        axis="columns", how="all").convert_dtypes().astype(
        {"UNITID": "category", "OPEID6": "category", "OPEID": "category"})
college_scorecard_institution.head(10)
# Out:
# C:\Users\raffertyp\.conda\envs\college-scorecard-analysis\Lib\site-packages\pandas\core\dtypes\cast.py:1057: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
# C:\Users\raffertyp\.conda\envs\college-scorecard-analysis\Lib\site-packages\pandas\core\dtypes\cast.py:1081: RuntimeWarning: invalid value encountered in cast
#   if (arr.astype(int) == arr).all():
#    UNITID    OPEID OPEID6                               INSTNM  \
# 0  100654   100200   1002             Alabama A & M University
# 1  100663   105200   1052  University of Alabama at Birmingham
# 2  100690  2503400  25034                   Amridge University
# 3  100706   105500   1055  University of Alabama in Huntsville
# 4  100724   100500   1005             Alabama State University
# 5  100751   105100   1051            The University of Alabama
# 6  100760   100700   1007    Central Alabama Community College
# 7  100812   100800   1008              Athens State University
# 8  100830   831000   8310      Auburn University at Montgomery
# 9  100858   100900   1009                    Auburn University
#
#              CITY STABBR         ZIP  \
# 0          Normal     AL       35762
# 1      Birmingham     AL  35294-0110
# 2      Montgomery     AL  36117-3553
# 3      Huntsville     AL       35899
# 4      Montgomery     AL  36104-0271
# 5      Tuscaloosa     AL  35487-0100
# 6  Alexander City     AL       35010
# 7          Athens     AL       35611
# 8      Montgomery     AL  36117-3596
# 9          Auburn     AL       36849
#
#                                         ACCREDAGENCY  \
# 0  Southern Association of Colleges and Schools C...
# 1  Southern Association of Colleges and Schools C...
# 2  Southern Association of Colleges and Schools C...
# 3  Southern Association of Colleges and Schools C...
# 4  Southern Association of Colleges and Schools C...
# 5  Southern Association of Colleges and Schools C...
# 6  Southern Association of Colleges and Schools C...
# 7  Southern Association of Colleges and Schools C...
# 8  Southern Association of Colleges and Schools C...
# 9  Southern Association of Colleges and Schools C...
#
#                               INSTURL  \
# 0                       www.aamu.edu/
# 1                https://www.uab.edu/
# 2  https://www.amridgeuniversity.edu/
# 3                        www.uah.edu/
# 4                      www.alasu.edu/
# 5                         www.ua.edu/
# 6                       www.cacc.edu/
# 7                     www.athens.edu/
# 8                        www.aum.edu/
# 9                     www.auburn.edu/
#
#                                               NPCURL  ...  \
# 0  www.aamu.edu/admissions-aid/tuition-fees/net-p...  ...
# 1  https://tcc.ruffalonl.com/University of Alabam...  ...
# 2           https://www2.amridgeuniversity.edu:9091/  ...
# 3                                    finaid.uah.edu/  ...
# 4  www.alasu.edu/cost-aid/tuition-costs/net-price...  ...
# 5          financialaid.ua.edu/net-price-calculator/  ...
# 6         https://www.cacc.edu/net-price-calculator/  ...
# 7  www.athens.edu/financial-aid/net-price-calcula...  ...
# 8  www.aum.edu/current-students/financial-informa...  ...
# 9  https://www.auburn.edu/admissions/costcalc/fre...  ...
#
#    OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                    0.3187                    0.2709
# 1                    0.6937                     0.066
# 2                       0.0                       0.5
# 3                    0.6471                    0.0941
# 4                    0.4381                    0.2167
# 5                    0.7532                    0.0433
# 6                    0.3264                    0.5397
# 7                      <NA>                      <NA>
# 8                    0.4058                    0.3037
# 9                    0.8171                     0.044
#
#    OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                       0.0128                       0.2949
# 1                       0.0111                       0.2636
# 2                          0.0                       0.3333
# 3                       0.0082                       0.2647
# 4                          0.0                       0.1444
# 5                       0.0096                       0.2351
# 6                          0.0                       0.1408
# 7                       0.0133                       0.1433
# 8                       0.0114                       0.2576
# 9                       0.0055                       0.1953
#
#    OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                       0.4744                       0.2179
# 1                       0.5136                       0.2117
# 2                       0.4583                       0.2083
# 3                       0.5948                       0.1324
# 4                       0.3667                       0.4889
# 5                       0.6292                       0.1261
# 6                       0.2958                       0.5634
# 7                       0.6219                       0.2216
# 8                       0.4962                       0.2348
# 9                       0.7347                       0.0644
#
#    OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  OMACHT8_NOPELL_NOTFIRSTTIME  \
# 0                 329                       251                           78
# 1                2358                      1182                         1176
# 2                  26                         2                           24
# 3                1122                       510                          612
# 4                 510                       420                           90
# 5                6774                      5315                         1459
# 6                 310                       239                           71
# 7                 677                         0                          677
# 8                 646                       382                          264
# 9                4154                      3253                          901
#
#                              ADDR
# 0            4900 Meridian Street
# 1  Administration Bldg Suite 1070
# 2                  1200 Taylor Rd
# 3                 301 Sparkman Dr
# 4            915 S Jackson Street
# 5             739 University Blvd
# 6                1675 Cherokee Rd
# 7                  300 N Beaty St
# 8                 7440 East Drive
# 9                 Auburn, Alabama
#
# [10 rows x 798 columns]

# %%
# Using Pandas' built-in zip support does not work since our zip file has more than one file 
# archived inside.
with zipfile.ZipFile("data/CollegeScorecard_Raw_Data_09262023.zip").open(
        "data/FieldOfStudyData1819_1920_PP.csv") as data_csv:
    college_scorecard_field_of_study = pd.read_csv(data_csv, low_memory=False,
                                                   na_values=("NULL", "PrivacySuppressed")).dropna(
        axis="columns", how="all").convert_dtypes().astype(
        {"UNITID": "category", "OPEID6": "category"})
college_scorecard_field_of_study.head(10)
# Out:
#    UNITID OPEID6                    INSTNM CONTROL  MAIN  CIPCODE  \
# 0  100654   1002  Alabama A & M University  Public     1      100
# 1  100654   1002  Alabama A & M University  Public     1      101
# 2  100654   1002  Alabama A & M University  Public     1      109
# 3  100654   1002  Alabama A & M University  Public     1      110
# 4  100654   1002  Alabama A & M University  Public     1      110
# 5  100654   1002  Alabama A & M University  Public     1      110
# 6  100654   1002  Alabama A & M University  Public     1      111
# 7  100654   1002  Alabama A & M University  Public     1      199
# 8  100654   1002  Alabama A & M University  Public     1      199
# 9  100654   1002  Alabama A & M University  Public     1      199
#
#                                              CIPDESC  CREDLEV  \
# 0                              Agriculture, General.        3
# 1              Agricultural Business and Management.        3
# 2                                   Animal Sciences.        3
# 3                       Food Science and Technology.        3
# 4                       Food Science and Technology.        5
# 5                       Food Science and Technology.        6
# 6                                    Plant Sciences.        3
# 7  Agriculture, Agriculture Operations, and Relat...        3
# 8  Agriculture, Agriculture Operations, and Relat...        5
# 9  Agriculture, Agriculture Operations, and Relat...        6
#
#             CREDDESC  IPEDSCOUNT1  ...  BBRR4_FED_COMP_N  BBRR4_FED_COMP_DFLT  \
# 0  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 1  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 2  Bachelor's Degree            6  ...              <NA>                 <NA>
# 3  Bachelor's Degree            7  ...              <NA>                 <NA>
# 4    Master's Degree            8  ...                12                 <NA>
# 5    Doctoral Degree            2  ...              <NA>                 <NA>
# 6  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 7  Bachelor's Degree            2  ...              <NA>                 <NA>
# 8    Master's Degree            2  ...              <NA>                 <NA>
# 9    Doctoral Degree            2  ...              <NA>                 <NA>
#
#    BBRR4_FED_COMP_DLNQ  BBRR4_FED_COMP_FBR  BBRR4_FED_COMP_DFR  \
# 0                 <NA>                <NA>                <NA>
# 1                 <NA>                <NA>                <NA>
# 2                 <NA>                <NA>                <NA>
# 3                 <NA>                <NA>                <NA>
# 4                 <NA>                <NA>                <NA>
# 5                 <NA>                <NA>                <NA>
# 6                 <NA>                <NA>                <NA>
# 7                 <NA>                <NA>                <NA>
# 8                 <NA>                <NA>                <NA>
# 9                 <NA>                <NA>                <NA>
#
#    BBRR4_FED_COMP_NOPROG  BBRR4_FED_COMP_MAKEPROG  BBRR4_FED_COMP_PAIDINFULL  \
# 0                   <NA>                     <NA>                       <NA>
# 1                   <NA>                     <NA>                       <NA>
# 2                   <NA>                     <NA>                       <NA>
# 3                   <NA>                     <NA>                       <NA>
# 4                   <NA>                     <NA>                       <NA>
# 5                   <NA>                     <NA>                       <NA>
# 6                   <NA>                     <NA>                       <NA>
# 7                   <NA>                     <NA>                       <NA>
# 8                   <NA>                     <NA>                       <NA>
# 9                   <NA>                     <NA>                       <NA>
#
#    BBRR4_FED_COMP_DISCHARGE  DISTANCE
# 0                      <NA>         0
# 1                      <NA>         0
# 2                      <NA>         1
# 3                      <NA>         1
# 4                      <NA>         1
# 5                      <NA>         1
# 6                      <NA>         0
# 7                      <NA>         1
# 8                      <NA>         1
# 9                      <NA>         1
#
# [10 rows x 122 columns]

# %%
joined_college_scorecard = college_scorecard_field_of_study.join(college_scorecard_institution,
                                                                 "UNITID", rsuffix="dupe",
                                                                 validate="many_to_one")
joined_college_scorecard = joined_college_scorecard.drop(
    columns=filter(lambda label: "dupe" in label, joined_college_scorecard.columns))
joined_college_scorecard
# Out:
#         UNITID OPEID6                              INSTNM  \
# 0       100654   1002            Alabama A & M University
# 1       100654   1002            Alabama A & M University
# 2       100654   1002            Alabama A & M University
# 3       100654   1002            Alabama A & M University
# 4       100654   1002            Alabama A & M University
# ...        ...    ...                                 ...
# 233974    <NA>  42640      California Southern University
# 233975    <NA>  42640      California Southern University
# 233976    <NA>  42924  Body Wisdom Massage Therapy School
# 233977    <NA>  42961            Madera Community College
# 233978    <NA>  42961            Madera Community College
#
#                     CONTROL  MAIN  CIPCODE  \
# 0                    Public     1      100
# 1                    Public     1      101
# 2                    Public     1      109
# 3                    Public     1      110
# 4                    Public     1      110
# ...                     ...   ...      ...
# 233974  Private, for-profit     1     4228
# 233975  Private, for-profit     1     5138
# 233976  Private, for-profit     1     5135
# 233977               Public     1     2401
# 233978               Public     1     5138
#
#                                                   CIPDESC  CREDLEV  \
# 0                                   Agriculture, General.        3
# 1                   Agricultural Business and Management.        3
# 2                                        Animal Sciences.        3
# 3                            Food Science and Technology.        3
# 4                            Food Science and Technology.        5
# ...                                                   ...      ...
# 233974       Clinical, Counseling and Applied Psychology.        7
# 233975  Registered Nursing, Nursing Administration, Nu...        3
# 233976  Somatic Bodywork and Related Therapeutic Servi...        1
# 233977  Liberal Arts and Sciences, General Studies and...        2
# 233978  Registered Nursing, Nursing Administration, Nu...        2
#
#                                     CREDDESC  IPEDSCOUNT1  ...  \
# 0                          Bachelor's Degree         <NA>  ...
# 1                          Bachelor's Degree         <NA>  ...
# 2                          Bachelor's Degree            6  ...
# 3                          Bachelor's Degree            7  ...
# 4                            Master's Degree            8  ...
# ...                                      ...          ...  ...
# 233974             First Professional Degree         <NA>  ...
# 233975                     Bachelor's Degree         <NA>  ...
# 233976  Undergraduate Certificate or Diploma         <NA>  ...
# 233977                    Associate's Degree         <NA>  ...
# 233978                    Associate's Degree         <NA>  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                           <NA>                      <NA>
# 1                           <NA>                      <NA>
# 2                           <NA>                      <NA>
# 3                           <NA>                      <NA>
# 4                           <NA>                      <NA>
# ...                          ...                       ...
# 233974                      <NA>                      <NA>
# 233975                      <NA>                      <NA>
# 233976                      <NA>                      <NA>
# 233977                      <NA>                      <NA>
# 233978                      <NA>                      <NA>
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3                              <NA>                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3                              <NA>                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 0                     <NA>                      <NA>
# 1                     <NA>                      <NA>
# 2                     <NA>                      <NA>
# 3                     <NA>                      <NA>
# 4                     <NA>                      <NA>
# ...                    ...                       ...
# 233974                <NA>                      <NA>
# 233975                <NA>                      <NA>
# 233976                <NA>                      <NA>
# 233977                <NA>                      <NA>
# 233978                <NA>                      <NA>
#
#         OMACHT8_NOPELL_NOTFIRSTTIME  ADDR
# 0                              <NA>  <NA>
# 1                              <NA>  <NA>
# 2                              <NA>  <NA>
# 3                              <NA>  <NA>
# 4                              <NA>  <NA>
# ...                             ...   ...
# 233974                         <NA>  <NA>
# 233975                         <NA>  <NA>
# 233976                         <NA>  <NA>
# 233977                         <NA>  <NA>
# 233978                         <NA>  <NA>
#
# [233979 rows x 915 columns]

# %%
for col in joined_college_scorecard.columns: 
    unique_cols = joined_college_scorecard[col].unique()
    if len(unique_cols) <= 3 and 0 in unique_cols and 1 in unique_cols:
        print(col)
        joined_college_scorecard[col] = joined_college_scorecard[col].astype("boolean")
        #todo: not catching DISTANCEONLY case
joined_college_scorecard
# Out:
# MAIN
#         UNITID OPEID6                              INSTNM  \
# 0       100654   1002            Alabama A & M University
# 1       100654   1002            Alabama A & M University
# 2       100654   1002            Alabama A & M University
# 3       100654   1002            Alabama A & M University
# 4       100654   1002            Alabama A & M University
# ...        ...    ...                                 ...
# 233974    <NA>  42640      California Southern University
# 233975    <NA>  42640      California Southern University
# 233976    <NA>  42924  Body Wisdom Massage Therapy School
# 233977    <NA>  42961            Madera Community College
# 233978    <NA>  42961            Madera Community College
#
#                     CONTROL  MAIN  CIPCODE  \
# 0                    Public  True      100
# 1                    Public  True      101
# 2                    Public  True      109
# 3                    Public  True      110
# 4                    Public  True      110
# ...                     ...   ...      ...
# 233974  Private, for-profit  True     4228
# 233975  Private, for-profit  True     5138
# 233976  Private, for-profit  True     5135
# 233977               Public  True     2401
# 233978               Public  True     5138
#
#                                                   CIPDESC  CREDLEV  \
# 0                                   Agriculture, General.        3
# 1                   Agricultural Business and Management.        3
# 2                                        Animal Sciences.        3
# 3                            Food Science and Technology.        3
# 4                            Food Science and Technology.        5
# ...                                                   ...      ...
# 233974       Clinical, Counseling and Applied Psychology.        7
# 233975  Registered Nursing, Nursing Administration, Nu...        3
# 233976  Somatic Bodywork and Related Therapeutic Servi...        1
# 233977  Liberal Arts and Sciences, General Studies and...        2
# 233978  Registered Nursing, Nursing Administration, Nu...        2
#
#                                     CREDDESC  IPEDSCOUNT1  ...  \
# 0                          Bachelor's Degree         <NA>  ...
# 1                          Bachelor's Degree         <NA>  ...
# 2                          Bachelor's Degree            6  ...
# 3                          Bachelor's Degree            7  ...
# 4                            Master's Degree            8  ...
# ...                                      ...          ...  ...
# 233974             First Professional Degree         <NA>  ...
# 233975                     Bachelor's Degree         <NA>  ...
# 233976  Undergraduate Certificate or Diploma         <NA>  ...
# 233977                    Associate's Degree         <NA>  ...
# 233978                    Associate's Degree         <NA>  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                           <NA>                      <NA>
# 1                           <NA>                      <NA>
# 2                           <NA>                      <NA>
# 3                           <NA>                      <NA>
# 4                           <NA>                      <NA>
# ...                          ...                       ...
# 233974                      <NA>                      <NA>
# 233975                      <NA>                      <NA>
# 233976                      <NA>                      <NA>
# 233977                      <NA>                      <NA>
# 233978                      <NA>                      <NA>
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3                              <NA>                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                              <NA>                         <NA>
# 1                              <NA>                         <NA>
# 2                              <NA>                         <NA>
# 3                              <NA>                         <NA>
# 4                              <NA>                         <NA>
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 0                     <NA>                      <NA>
# 1                     <NA>                      <NA>
# 2                     <NA>                      <NA>
# 3                     <NA>                      <NA>
# 4                     <NA>                      <NA>
# ...                    ...                       ...
# 233974                <NA>                      <NA>
# 233975                <NA>                      <NA>
# 233976                <NA>                      <NA>
# 233977                <NA>                      <NA>
# 233978                <NA>                      <NA>
#
#         OMACHT8_NOPELL_NOTFIRSTTIME  ADDR
# 0                              <NA>  <NA>
# 1                              <NA>  <NA>
# 2                              <NA>  <NA>
# 3                              <NA>  <NA>
# 4                              <NA>  <NA>
# ...                             ...   ...
# 233974                         <NA>  <NA>
# 233975                         <NA>  <NA>
# 233976                         <NA>  <NA>
# 233977                         <NA>  <NA>
# 233978                         <NA>  <NA>
#
# [233979 rows x 915 columns]

# %%
joined_college_scorecard[joined_college_scorecard["INSTNM"] == "Milwaukee School of Engineering"]
# Out:
#         UNITID OPEID6                           INSTNM             CONTROL  \
# 192794  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192795  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192796  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192797  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192798  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192799  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192800  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192801  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192802  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192803  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192804  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192805  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192806  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192807  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192808  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192809  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192810  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192811  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192812  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192813  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192814  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192815  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192816  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192817  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192818  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192819  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192820  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192821  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192822  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192823  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192824  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192825  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192826  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192827  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192828  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192829  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192830  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192831  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192832  239318   3868  Milwaukee School of Engineering  Private, nonprofit
# 192833  239318   3868  Milwaukee School of Engineering  Private, nonprofit
#
#         MAIN  CIPCODE                                            CIPDESC  \
# 192794  True      909  Public Relations, Advertising, and Applied Com...
# 192795  True     1107                                  Computer Science.
# 192796  True     1108          Computer Software and Media Applications.
# 192797  True     1401                              Engineering, General.
# 192798  True     1401                              Engineering, General.
# 192799  True     1404                         Architectural Engineering.
# 192800  True     1404                         Architectural Engineering.
# 192801  True     1405                    Biomedical/Medical Engineering.
# 192802  True     1407                              Chemical Engineering.
# 192803  True     1408                                 Civil Engineering.
# 192804  True     1408                                 Civil Engineering.
# 192805  True     1409                              Computer Engineering.
# 192806  True     1410  Electrical, Electronics and Communications Eng...
# 192807  True     1414    Environmental/Environmental Health Engineering.
# 192808  True     1419                            Mechanical Engineering.
# 192809  True     1435                            Industrial Engineering.
# 192810  True     1437                               Operations Research.
# 192811  True     1503   Electrical Engineering Technologies/Technicians.
# 192812  True     1508  Mechanical Engineering Related Technologies/Te...
# 192813  True     2609        Physiology, Pathology and Related Sciences.
# 192814  True     3031                        Human Computer Interaction.
# 192815  True     5109  Allied Health Diagnostic, Intervention, and Tr...
# 192816  True     5127              Medical Illustration and Informatics.
# 192817  True     5138  Registered Nursing, Nursing Administration, Nu...
# 192818  True     5138  Registered Nursing, Nursing Administration, Nu...
# 192819  True     5138  Registered Nursing, Nursing Administration, Nu...
# 192820  True     5201                        Business/Commerce, General.
# 192821  True     5202  Business Administration, Management and Operat...
# 192822  True     5202  Business Administration, Management and Operat...
# 192823  True     5202  Business Administration, Management and Operat...
# 192824  True     5207     Entrepreneurial and Small Business Operations.
# 192825  True     5211                            International Business.
# 192826  True     5211                            International Business.
# 192827  True     5211                            International Business.
# 192828  True     5212       Management Information Systems and Services.
# 192829  True     5212       Management Information Systems and Services.
# 192830  True     5213      Management Sciences and Quantitative Methods.
# 192831  True     5213      Management Sciences and Quantitative Methods.
# 192832  True     5220                           Construction Management.
# 192833  True     5220                           Construction Management.
#
#         CREDLEV                              CREDDESC  IPEDSCOUNT1  ...  \
# 192794        3                     Bachelor's Degree            1  ...
# 192795        3                     Bachelor's Degree         <NA>  ...
# 192796        1  Undergraduate Certificate or Diploma            1  ...
# 192797        3                     Bachelor's Degree            2  ...
# 192798        5                       Master's Degree            9  ...
# 192799        3                     Bachelor's Degree           23  ...
# 192800        5                       Master's Degree            8  ...
# 192801        3                     Bachelor's Degree           44  ...
# 192802        3                     Bachelor's Degree           18  ...
# 192803        3                     Bachelor's Degree           16  ...
# 192804        5                       Master's Degree           12  ...
# 192805        3                     Bachelor's Degree           80  ...
# 192806        3                     Bachelor's Degree           87  ...
# 192807        5                       Master's Degree            0  ...
# 192808        3                     Bachelor's Degree          122  ...
# 192809        3                     Bachelor's Degree           39  ...
# 192810        3                     Bachelor's Degree            0  ...
# 192811        3                     Bachelor's Degree            0  ...
# 192812        3                     Bachelor's Degree            0  ...
# 192813        5                       Master's Degree            0  ...
# 192814        3                     Bachelor's Degree            1  ...
# 192815        5                       Master's Degree            7  ...
# 192816        5                       Master's Degree            1  ...
# 192817        3                     Bachelor's Degree           68  ...
# 192818        5                       Master's Degree            4  ...
# 192819        8     Graduate/Professional Certificate         <NA>  ...
# 192820        3                     Bachelor's Degree            0  ...
# 192821        3                     Bachelor's Degree           18  ...
# 192822        5                       Master's Degree           76  ...
# 192823        8     Graduate/Professional Certificate           11  ...
# 192824        8     Graduate/Professional Certificate            5  ...
# 192825        3                     Bachelor's Degree            4  ...
# 192826        5                       Master's Degree            0  ...
# 192827        8     Graduate/Professional Certificate            0  ...
# 192828        3                     Bachelor's Degree            5  ...
# 192829        8     Graduate/Professional Certificate            3  ...
# 192830        3                     Bachelor's Degree            7  ...
# 192831        8     Graduate/Professional Certificate         <NA>  ...
# 192832        3                     Bachelor's Degree           14  ...
# 192833        5                       Master's Degree            1  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 192794                      <NA>                      <NA>
# 192795                      <NA>                      <NA>
# 192796                      <NA>                      <NA>
# 192797                      <NA>                      <NA>
# 192798                      <NA>                      <NA>
# 192799                      <NA>                      <NA>
# 192800                      <NA>                      <NA>
# 192801                      <NA>                      <NA>
# 192802                      <NA>                      <NA>
# 192803                      <NA>                      <NA>
# 192804                      <NA>                      <NA>
# 192805                      <NA>                      <NA>
# 192806                      <NA>                      <NA>
# 192807                      <NA>                      <NA>
# 192808                      <NA>                      <NA>
# 192809                      <NA>                      <NA>
# 192810                      <NA>                      <NA>
# 192811                      <NA>                      <NA>
# 192812                      <NA>                      <NA>
# 192813                      <NA>                      <NA>
# 192814                      <NA>                      <NA>
# 192815                      <NA>                      <NA>
# 192816                      <NA>                      <NA>
# 192817                      <NA>                      <NA>
# 192818                      <NA>                      <NA>
# 192819                      <NA>                      <NA>
# 192820                      <NA>                      <NA>
# 192821                      <NA>                      <NA>
# 192822                      <NA>                      <NA>
# 192823                      <NA>                      <NA>
# 192824                      <NA>                      <NA>
# 192825                      <NA>                      <NA>
# 192826                      <NA>                      <NA>
# 192827                      <NA>                      <NA>
# 192828                      <NA>                      <NA>
# 192829                      <NA>                      <NA>
# 192830                      <NA>                      <NA>
# 192831                      <NA>                      <NA>
# 192832                      <NA>                      <NA>
# 192833                      <NA>                      <NA>
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 192794                         <NA>                         <NA>
# 192795                         <NA>                         <NA>
# 192796                         <NA>                         <NA>
# 192797                         <NA>                         <NA>
# 192798                         <NA>                         <NA>
# 192799                         <NA>                         <NA>
# 192800                         <NA>                         <NA>
# 192801                         <NA>                         <NA>
# 192802                         <NA>                         <NA>
# 192803                         <NA>                         <NA>
# 192804                         <NA>                         <NA>
# 192805                         <NA>                         <NA>
# 192806                         <NA>                         <NA>
# 192807                         <NA>                         <NA>
# 192808                         <NA>                         <NA>
# 192809                         <NA>                         <NA>
# 192810                         <NA>                         <NA>
# 192811                         <NA>                         <NA>
# 192812                         <NA>                         <NA>
# 192813                         <NA>                         <NA>
# 192814                         <NA>                         <NA>
# 192815                         <NA>                         <NA>
# 192816                         <NA>                         <NA>
# 192817                         <NA>                         <NA>
# 192818                         <NA>                         <NA>
# 192819                         <NA>                         <NA>
# 192820                         <NA>                         <NA>
# 192821                         <NA>                         <NA>
# 192822                         <NA>                         <NA>
# 192823                         <NA>                         <NA>
# 192824                         <NA>                         <NA>
# 192825                         <NA>                         <NA>
# 192826                         <NA>                         <NA>
# 192827                         <NA>                         <NA>
# 192828                         <NA>                         <NA>
# 192829                         <NA>                         <NA>
# 192830                         <NA>                         <NA>
# 192831                         <NA>                         <NA>
# 192832                         <NA>                         <NA>
# 192833                         <NA>                         <NA>
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 192794                         <NA>                         <NA>
# 192795                         <NA>                         <NA>
# 192796                         <NA>                         <NA>
# 192797                         <NA>                         <NA>
# 192798                         <NA>                         <NA>
# 192799                         <NA>                         <NA>
# 192800                         <NA>                         <NA>
# 192801                         <NA>                         <NA>
# 192802                         <NA>                         <NA>
# 192803                         <NA>                         <NA>
# 192804                         <NA>                         <NA>
# 192805                         <NA>                         <NA>
# 192806                         <NA>                         <NA>
# 192807                         <NA>                         <NA>
# 192808                         <NA>                         <NA>
# 192809                         <NA>                         <NA>
# 192810                         <NA>                         <NA>
# 192811                         <NA>                         <NA>
# 192812                         <NA>                         <NA>
# 192813                         <NA>                         <NA>
# 192814                         <NA>                         <NA>
# 192815                         <NA>                         <NA>
# 192816                         <NA>                         <NA>
# 192817                         <NA>                         <NA>
# 192818                         <NA>                         <NA>
# 192819                         <NA>                         <NA>
# 192820                         <NA>                         <NA>
# 192821                         <NA>                         <NA>
# 192822                         <NA>                         <NA>
# 192823                         <NA>                         <NA>
# 192824                         <NA>                         <NA>
# 192825                         <NA>                         <NA>
# 192826                         <NA>                         <NA>
# 192827                         <NA>                         <NA>
# 192828                         <NA>                         <NA>
# 192829                         <NA>                         <NA>
# 192830                         <NA>                         <NA>
# 192831                         <NA>                         <NA>
# 192832                         <NA>                         <NA>
# 192833                         <NA>                         <NA>
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 192794                <NA>                      <NA>
# 192795                <NA>                      <NA>
# 192796                <NA>                      <NA>
# 192797                <NA>                      <NA>
# 192798                <NA>                      <NA>
# 192799                <NA>                      <NA>
# 192800                <NA>                      <NA>
# 192801                <NA>                      <NA>
# 192802                <NA>                      <NA>
# 192803                <NA>                      <NA>
# 192804                <NA>                      <NA>
# 192805                <NA>                      <NA>
# 192806                <NA>                      <NA>
# 192807                <NA>                      <NA>
# 192808                <NA>                      <NA>
# 192809                <NA>                      <NA>
# 192810                <NA>                      <NA>
# 192811                <NA>                      <NA>
# 192812                <NA>                      <NA>
# 192813                <NA>                      <NA>
# 192814                <NA>                      <NA>
# 192815                <NA>                      <NA>
# 192816                <NA>                      <NA>
# 192817                <NA>                      <NA>
# 192818                <NA>                      <NA>
# 192819                <NA>                      <NA>
# 192820                <NA>                      <NA>
# 192821                <NA>                      <NA>
# 192822                <NA>                      <NA>
# 192823                <NA>                      <NA>
# 192824                <NA>                      <NA>
# 192825                <NA>                      <NA>
# 192826                <NA>                      <NA>
# 192827                <NA>                      <NA>
# 192828                <NA>                      <NA>
# 192829                <NA>                      <NA>
# 192830                <NA>                      <NA>
# 192831                <NA>                      <NA>
# 192832                <NA>                      <NA>
# 192833                <NA>                      <NA>
#
#         OMACHT8_NOPELL_NOTFIRSTTIME  ADDR
# 192794                         <NA>  <NA>
# 192795                         <NA>  <NA>
# 192796                         <NA>  <NA>
# 192797                         <NA>  <NA>
# 192798                         <NA>  <NA>
# 192799                         <NA>  <NA>
# 192800                         <NA>  <NA>
# 192801                         <NA>  <NA>
# 192802                         <NA>  <NA>
# 192803                         <NA>  <NA>
# 192804                         <NA>  <NA>
# 192805                         <NA>  <NA>
# 192806                         <NA>  <NA>
# 192807                         <NA>  <NA>
# 192808                         <NA>  <NA>
# 192809                         <NA>  <NA>
# 192810                         <NA>  <NA>
# 192811                         <NA>  <NA>
# 192812                         <NA>  <NA>
# 192813                         <NA>  <NA>
# 192814                         <NA>  <NA>
# 192815                         <NA>  <NA>
# 192816                         <NA>  <NA>
# 192817                         <NA>  <NA>
# 192818                         <NA>  <NA>
# 192819                         <NA>  <NA>
# 192820                         <NA>  <NA>
# 192821                         <NA>  <NA>
# 192822                         <NA>  <NA>
# 192823                         <NA>  <NA>
# 192824                         <NA>  <NA>
# 192825                         <NA>  <NA>
# 192826                         <NA>  <NA>
# 192827                         <NA>  <NA>
# 192828                         <NA>  <NA>
# 192829                         <NA>  <NA>
# 192830                         <NA>  <NA>
# 192831                         <NA>  <NA>
# 192832                         <NA>  <NA>
# 192833                         <NA>  <NA>
#
# [40 rows x 915 columns]

# %% [markdown]
# # Debt Column Key

# %% [markdown]
# Format: DEBT_[Disaggregation]_[Loan Type]_[Method]_[Metric]

# %% [markdown]
# ## Disaggregation

# %% [markdown]
# - MALE: Men only

# %% [markdown]
# - NOTMALE: Women only

# %% [markdown]
# - PELL: People who got Pell grants.

# %% [markdown]
# - NOPELL: People who did not receive Pell grants.

# %% [markdown]
# - ALL: All graduates, no disaggregation

# %% [markdown]
# ## Loan Type

# %% [markdown]
# - STGP: Stafford and Graduate Plus loans

# %% [markdown]
# - PP: Parent Plus loans

# %% [markdown]
# ## Method

# %% [markdown]
# - EVAL: Debts originated only at the specified institution.

# %% [markdown]
# - ANY: Debts originated at any institution attended by graduates.

# %% [markdown]
# ## Metric

# %% [markdown]
# - N: number of grads with loans

# %% [markdown]
# - MDN: Median loan amount dispersed.

# %% [markdown]
# - MEAN: Mean loan amount dispersed.

# %%
pd.DataFrame(joined_college_scorecard[
                 filter(lambda label: "DEBT" in label, joined_college_scorecard.columns)].columns)
# Out:
#                                 0
# 0             DEBT_ALL_STGP_ANY_N
# 1          DEBT_ALL_STGP_ANY_MEAN
# 2           DEBT_ALL_STGP_ANY_MDN
# 3            DEBT_ALL_STGP_EVAL_N
# 4         DEBT_ALL_STGP_EVAL_MEAN
# ..                            ...
# 59        DEBT_NOPELL_PP_EVAL_MDN
# 60     DEBT_ALL_PP_ANY_MDN10YRPAY
# 61    DEBT_ALL_PP_EVAL_MDN10YRPAY
# 62   DEBT_ALL_STGP_ANY_MDN10YRPAY
# 63  DEBT_ALL_STGP_EVAL_MDN10YRPAY
#
# [64 rows x 1 columns]

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Search for potential linear relationships

# %%
pd.DataFrame(joined_college_scorecard.dtypes)
# Out:
#                                           0
# UNITID                                Int64
# OPEID6                             category
# INSTNM                       string[python]
# CONTROL                      string[python]
# MAIN                                boolean
# ...                                     ...
# OMENRUP_NOPELL_NOTFIRSTTIME         Float64
# OMACHT8_NOPELL_ALL                    Int64
# OMACHT8_NOPELL_FIRSTTIME              Int64
# OMACHT8_NOPELL_NOTFIRSTTIME           Int64
# ADDR                         string[python]
#
# [915 rows x 1 columns]

# %%
numeric_variables = tuple(filter(lambda col: (joined_college_scorecard[col].dtype == "Float64" or
                                              joined_college_scorecard[
                                                  col].dtype == "Int64") and not "DEBT" in col,
                                 joined_college_scorecard.columns))

dat = {}

for column in numeric_variables:
    nonna_subset = joined_college_scorecard[[column, "DEBT_ALL_STGP_ANY_MDN"]].dropna()
    if len(nonna_subset >= 2):
        res = stats.pearsonr(nonna_subset["DEBT_ALL_STGP_ANY_MDN"], nonna_subset[column])
        dat[column] = {"R": res[0], "p-value": res[1]}

df = pd.DataFrame.from_dict(dat, orient='index')
df.reset_index(inplace=True)
df.rename(columns={'index': 'Column', 'R': 'Statistic'}, inplace=True)
df
# Out:
#                        Column  Statistic        p-value
# 0                      UNITID  -0.000877   8.598219e-01
# 1                     CIPCODE   0.008516   8.579278e-02
# 2                     CREDLEV   0.560083   0.000000e+00
# 3                 IPEDSCOUNT1  -0.140506  6.323998e-170
# 4                 IPEDSCOUNT2  -0.129043  1.729038e-140
# 5     EARN_COUNT_PELL_WNE_1YR   0.047477   9.628173e-16
# 6       EARN_PELL_WNE_MDN_1YR   0.277665   0.000000e+00
# 7   EARN_COUNT_NOPELL_WNE_1YR   0.111177   5.803865e-46
# 8     EARN_NOPELL_WNE_MDN_1YR   0.321291   0.000000e+00
# 9     EARN_COUNT_MALE_WNE_1YR   0.056154   1.452166e-14
# 10      EARN_MALE_WNE_MDN_1YR   0.282473   0.000000e+00
# 11  EARN_COUNT_NOMALE_WNE_1YR   0.048530   9.452422e-15
# 12    EARN_NOMALE_WNE_MDN_1YR   0.279773   0.000000e+00
# 13        EARN_COUNT_NWNE_1YR  -0.033923   8.572817e-12
# 14         EARN_COUNT_WNE_1YR   0.053687   5.310292e-24
# 15               EARN_MDN_1YR   0.253301   0.000000e+00
# 16      EARN_GT_THRESHOLD_1YR   0.165674   5.680633e-96
# 17   EARN_COUNT_HIGH_CRED_1YR   0.155760   2.208333e-08
# 18          EARN_IN_STATE_1YR  -0.064364   2.901780e-01
# 19        EARN_COUNT_NWNE_4YR   0.045606   5.435871e-19
# 20         EARN_COUNT_WNE_4YR   0.113533   1.845892e-91
# 21               EARN_MDN_4YR   0.237183   0.000000e+00
# 22      EARN_GT_THRESHOLD_4YR   0.241560  8.124083e-164
# 23    EARN_COUNT_PELL_WNE_4YR   0.117097   1.558538e-79
# 24      EARN_PELL_WNE_MDN_4YR   0.250019   0.000000e+00
# 25  EARN_COUNT_NOPELL_WNE_4YR   0.155069   9.727035e-81
# 26    EARN_NOPELL_WNE_MDN_4YR   0.294271  5.257517e-295
# 27    EARN_COUNT_MALE_WNE_4YR   0.129888   3.169800e-66
# 28      EARN_MALE_WNE_MDN_4YR   0.238089  2.141941e-222
# 29  EARN_COUNT_NOMALE_WNE_4YR   0.109548   5.816965e-62
# 30    EARN_NOMALE_WNE_MDN_4YR   0.276355   0.000000e+00
# 31   EARN_COUNT_HIGH_CRED_4YR   0.142044   8.130193e-36
# 32          EARN_IN_STATE_4YR  -0.111491   1.472954e-72
# 33           BBRR1_FED_COMP_N   0.044715   3.406761e-18
# 34           BBRR4_FED_COMP_N   0.111636   2.060205e-94
# 35                   DISTANCE   0.130230  2.095231e-153
