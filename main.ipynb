# %% [markdown]
# Patrick Marshall and Patrick Rafferty
#
# Introduction to Data Science
#
# Final Project Notebook
#
# 7 March 2024

# %% [markdown]
# # Objective
#
# Out of the features collected by the Department of Education in the "College Scorecard" dataset, which are the most influential on predicting student debt?

# %% [markdown]
# # Imports

# %%
# Imports
import urllib.request
import zipfile

import pandas as pd
from scipy import stats
from scipy.stats import kruskal
from sklearnex import ensemble
from sklearn import model_selection

# %% [markdown]
# # Data Loading

# %%
# Retrieve Data Zip File
if not zipfile.is_zipfile("data/CollegeScorecard_Raw_Data_09262023.zip"):
    urllib.request.urlretrieve("https://ed-public-download.app.cloud"
                               ".gov/downloads/CollegeScorecard_Raw_Data_09262023.zip",
                               "data/CollegeScorecard_Raw_Data_09262023.zip")

# %%
# Using Pandas' built-in zip support does not work since our zip file has more than one file 
# archived inside.
with (zipfile.ZipFile("data/CollegeScorecard_Raw_Data_09262023.zip").open(
        "data/Most-Recent-Cohorts-Institution.csv") as data_csv):
    college_scorecard_institution = pd.read_csv(data_csv, na_values=("NULL", "PrivacySuppressed"),
                                                true_values=["1"], false_values=["0"],
                                                index_col="UNITID", engine="pyarrow").dropna(
        axis="columns", how="all").convert_dtypes()
college_scorecard_institution.head(10)
# Out:
#           OPEID  OPEID6                               INSTNM            CITY  \
# UNITID
# 100654   100200    1002             Alabama A & M University          Normal
# 100663   105200    1052  University of Alabama at Birmingham      Birmingham
# 100690  2503400   25034                   Amridge University      Montgomery
# 100706   105500    1055  University of Alabama in Huntsville      Huntsville
# 100724   100500    1005             Alabama State University      Montgomery
# 100751   105100    1051            The University of Alabama      Tuscaloosa
# 100760   100700    1007    Central Alabama Community College  Alexander City
# 100812   100800    1008              Athens State University          Athens
# 100830   831000    8310      Auburn University at Montgomery      Montgomery
# 100858   100900    1009                    Auburn University          Auburn
#
#        STABBR         ZIP                                       ACCREDAGENCY  \
# UNITID
# 100654     AL       35762  Southern Association of Colleges and Schools C...
# 100663     AL  35294-0110  Southern Association of Colleges and Schools C...
# 100690     AL  36117-3553  Southern Association of Colleges and Schools C...
# 100706     AL       35899  Southern Association of Colleges and Schools C...
# 100724     AL  36104-0271  Southern Association of Colleges and Schools C...
# 100751     AL  35487-0100  Southern Association of Colleges and Schools C...
# 100760     AL       35010  Southern Association of Colleges and Schools C...
# 100812     AL       35611  Southern Association of Colleges and Schools C...
# 100830     AL  36117-3596  Southern Association of Colleges and Schools C...
# 100858     AL       36849  Southern Association of Colleges and Schools C...
#
#                                    INSTURL  \
# UNITID
# 100654                       www.aamu.edu/
# 100663                https://www.uab.edu/
# 100690  https://www.amridgeuniversity.edu/
# 100706                        www.uah.edu/
# 100724                      www.alasu.edu/
# 100751                         www.ua.edu/
# 100760                       www.cacc.edu/
# 100812                     www.athens.edu/
# 100830                        www.aum.edu/
# 100858                     www.auburn.edu/
#
#                                                    NPCURL  SCH_DEG  ...  \
# UNITID                                                              ...
# 100654  www.aamu.edu/admissions-aid/tuition-fees/net-p...        3  ...
# 100663  https://tcc.ruffalonl.com/University of Alabam...        3  ...
# 100690           https://www2.amridgeuniversity.edu:9091/        3  ...
# 100706                                    finaid.uah.edu/        3  ...
# 100724  www.alasu.edu/cost-aid/tuition-costs/net-price...        3  ...
# 100751          financialaid.ua.edu/net-price-calculator/        3  ...
# 100760         https://www.cacc.edu/net-price-calculator/        2  ...
# 100812  www.athens.edu/financial-aid/net-price-calcula...        3  ...
# 100830  www.aum.edu/current-students/financial-informa...        3  ...
# 100858  https://www.auburn.edu/admissions/costcalc/fre...        3  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# UNITID
# 100654                    0.3187                    0.2709
# 100663                    0.6937                     0.066
# 100690                       0.0                       0.5
# 100706                    0.6471                    0.0941
# 100724                    0.4381                    0.2167
# 100751                    0.7532                    0.0433
# 100760                    0.3264                    0.5397
# 100812                      <NA>                      <NA>
# 100830                    0.4058                    0.3037
# 100858                    0.8171                     0.044
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# UNITID
# 100654                       0.0128                       0.2949
# 100663                       0.0111                       0.2636
# 100690                          0.0                       0.3333
# 100706                       0.0082                       0.2647
# 100724                          0.0                       0.1444
# 100751                       0.0096                       0.2351
# 100760                          0.0                       0.1408
# 100812                       0.0133                       0.1433
# 100830                       0.0114                       0.2576
# 100858                       0.0055                       0.1953
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# UNITID
# 100654                       0.4744                       0.2179
# 100663                       0.5136                       0.2117
# 100690                       0.4583                       0.2083
# 100706                       0.5948                       0.1324
# 100724                       0.3667                       0.4889
# 100751                       0.6292                       0.1261
# 100760                       0.2958                       0.5634
# 100812                       0.6219                       0.2216
# 100830                       0.4962                       0.2348
# 100858                       0.7347                       0.0644
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# UNITID
# 100654                 329                       251
# 100663                2358                      1182
# 100690                  26                         2
# 100706                1122                       510
# 100724                 510                       420
# 100751                6774                      5315
# 100760                 310                       239
# 100812                 677                         0
# 100830                 646                       382
# 100858                4154                      3253
#
#         OMACHT8_NOPELL_NOTFIRSTTIME                            ADDR
# UNITID
# 100654                           78            4900 Meridian Street
# 100663                         1176  Administration Bldg Suite 1070
# 100690                           24                  1200 Taylor Rd
# 100706                          612                 301 Sparkman Dr
# 100724                           90            915 S Jackson Street
# 100751                         1459             739 University Blvd
# 100760                           71                1675 Cherokee Rd
# 100812                          677                  300 N Beaty St
# 100830                          264                 7440 East Drive
# 100858                          901                 Auburn, Alabama
#
# [10 rows x 3046 columns]

# %%
# Using Pandas' built-in zip support does not work since our zip file has more than one file 
# archived inside.
with (zipfile.ZipFile("data/CollegeScorecard_Raw_Data_09262023.zip").open(
        "data/Most-Recent-Cohorts-Field-of-Study.csv") as data_csv):
    college_scorecard_field_of_study = pd.read_csv(data_csv,
                                                   na_values=("NULL", "PrivacySuppressed"),
                                                   true_values=["1"], false_values=["0"],
                                                   engine="pyarrow").dropna(axis="columns",
                                                                            how="all").convert_dtypes()
college_scorecard_field_of_study.head(10)
# Out:
#    UNITID  OPEID6                    INSTNM CONTROL  MAIN  CIPCODE  \
# 0  100654    1002  Alabama A & M University  Public     1      100
# 1  100654    1002  Alabama A & M University  Public     1      101
# 2  100654    1002  Alabama A & M University  Public     1      109
# 3  100654    1002  Alabama A & M University  Public     1      110
# 4  100654    1002  Alabama A & M University  Public     1      110
# 5  100654    1002  Alabama A & M University  Public     1      110
# 6  100654    1002  Alabama A & M University  Public     1      111
# 7  100654    1002  Alabama A & M University  Public     1      199
# 8  100654    1002  Alabama A & M University  Public     1      199
# 9  100654    1002  Alabama A & M University  Public     1      199
#
#                                              CIPDESC  CREDLEV  \
# 0                              Agriculture, General.        3
# 1              Agricultural Business and Management.        3
# 2                                   Animal Sciences.        3
# 3                       Food Science and Technology.        3
# 4                       Food Science and Technology.        5
# 5                       Food Science and Technology.        6
# 6                                    Plant Sciences.        3
# 7  Agriculture, Agriculture Operations, and Relat...        3
# 8  Agriculture, Agriculture Operations, and Relat...        5
# 9  Agriculture, Agriculture Operations, and Relat...        6
#
#             CREDDESC  IPEDSCOUNT1  ...  BBRR4_FED_COMP_N  BBRR4_FED_COMP_DFLT  \
# 0  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 1  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 2  Bachelor's Degree            6  ...              <NA>                 <NA>
# 3  Bachelor's Degree            7  ...              <NA>                 <NA>
# 4    Master's Degree            8  ...                12                 <NA>
# 5    Doctoral Degree            2  ...              <NA>                 <NA>
# 6  Bachelor's Degree         <NA>  ...              <NA>                 <NA>
# 7  Bachelor's Degree            2  ...              <NA>                 <NA>
# 8    Master's Degree            2  ...              <NA>                 <NA>
# 9    Doctoral Degree            2  ...              <NA>                 <NA>
#
#    BBRR4_FED_COMP_DLNQ  BBRR4_FED_COMP_FBR  BBRR4_FED_COMP_DFR  \
# 0                 <NA>                <NA>                <NA>
# 1                 <NA>                <NA>                <NA>
# 2                 <NA>                <NA>                <NA>
# 3                 <NA>                <NA>                <NA>
# 4                 <NA>                <NA>                <NA>
# 5                 <NA>                <NA>                <NA>
# 6                 <NA>                <NA>                <NA>
# 7                 <NA>                <NA>                <NA>
# 8                 <NA>                <NA>                <NA>
# 9                 <NA>                <NA>                <NA>
#
#    BBRR4_FED_COMP_NOPROG  BBRR4_FED_COMP_MAKEPROG  BBRR4_FED_COMP_PAIDINFULL  \
# 0                   <NA>                     <NA>                       <NA>
# 1                   <NA>                     <NA>                       <NA>
# 2                   <NA>                     <NA>                       <NA>
# 3                   <NA>                     <NA>                       <NA>
# 4                   <NA>                     <NA>                       <NA>
# 5                   <NA>                     <NA>                       <NA>
# 6                   <NA>                     <NA>                       <NA>
# 7                   <NA>                     <NA>                       <NA>
# 8                   <NA>                     <NA>                       <NA>
# 9                   <NA>                     <NA>                       <NA>
#
#    BBRR4_FED_COMP_DISCHARGE  DISTANCE
# 0                      <NA>         0
# 1                      <NA>         0
# 2                      <NA>         1
# 3                      <NA>         1
# 4                      <NA>         1
# 5                      <NA>         1
# 6                      <NA>         0
# 7                      <NA>         1
# 8                      <NA>         1
# 9                      <NA>         1
#
# [10 rows x 160 columns]

# %%
joined_college_scorecard = (
    college_scorecard_field_of_study.join(other=college_scorecard_institution, on="UNITID",
                                          how="left", lsuffix="_field_of_study",
                                          rsuffix="_institution", validate="many_to_one"))
del college_scorecard_field_of_study
del college_scorecard_institution
joined_college_scorecard
# Out:
#         UNITID  OPEID6_field_of_study               INSTNM_field_of_study  \
# 0       100654                   1002            Alabama A & M University
# 1       100654                   1002            Alabama A & M University
# 2       100654                   1002            Alabama A & M University
# 3       100654                   1002            Alabama A & M University
# 4       100654                   1002            Alabama A & M University
# ...        ...                    ...                                 ...
# 233974    <NA>                  42640      California Southern University
# 233975    <NA>                  42640      California Southern University
# 233976    <NA>                  42924  Body Wisdom Massage Therapy School
# 233977    <NA>                  42961            Madera Community College
# 233978    <NA>                  42961            Madera Community College
#
#        CONTROL_field_of_study  MAIN_field_of_study  CIPCODE  \
# 0                      Public                    1      100
# 1                      Public                    1      101
# 2                      Public                    1      109
# 3                      Public                    1      110
# 4                      Public                    1      110
# ...                       ...                  ...      ...
# 233974    Private, for-profit                    1     4228
# 233975    Private, for-profit                    1     5138
# 233976    Private, for-profit                    1     5135
# 233977                 Public                    1     2401
# 233978                 Public                    1     5138
#
#                                                   CIPDESC  CREDLEV  \
# 0                                   Agriculture, General.        3
# 1                   Agricultural Business and Management.        3
# 2                                        Animal Sciences.        3
# 3                            Food Science and Technology.        3
# 4                            Food Science and Technology.        5
# ...                                                   ...      ...
# 233974       Clinical, Counseling and Applied Psychology.        7
# 233975  Registered Nursing, Nursing Administration, Nu...        3
# 233976  Somatic Bodywork and Related Therapeutic Servi...        1
# 233977  Liberal Arts and Sciences, General Studies and...        2
# 233978  Registered Nursing, Nursing Administration, Nu...        2
#
#                                     CREDDESC  IPEDSCOUNT1  ...  \
# 0                          Bachelor's Degree         <NA>  ...
# 1                          Bachelor's Degree         <NA>  ...
# 2                          Bachelor's Degree            6  ...
# 3                          Bachelor's Degree            7  ...
# 4                            Master's Degree            8  ...
# ...                                      ...          ...  ...
# 233974             First Professional Degree         <NA>  ...
# 233975                     Bachelor's Degree         <NA>  ...
# 233976  Undergraduate Certificate or Diploma         <NA>  ...
# 233977                    Associate's Degree         <NA>  ...
# 233978                    Associate's Degree         <NA>  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                         0.3187                    0.2709
# 1                         0.3187                    0.2709
# 2                         0.3187                    0.2709
# 3                         0.3187                    0.2709
# 4                         0.3187                    0.2709
# ...                          ...                       ...
# 233974                      <NA>                      <NA>
# 233975                      <NA>                      <NA>
# 233976                      <NA>                      <NA>
# 233977                      <NA>                      <NA>
# 233978                      <NA>                      <NA>
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                            0.0128                       0.2949
# 1                            0.0128                       0.2949
# 2                            0.0128                       0.2949
# 3                            0.0128                       0.2949
# 4                            0.0128                       0.2949
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                            0.4744                       0.2179
# 1                            0.4744                       0.2179
# 2                            0.4744                       0.2179
# 3                            0.4744                       0.2179
# 4                            0.4744                       0.2179
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 0                      329                       251
# 1                      329                       251
# 2                      329                       251
# 3                      329                       251
# 4                      329                       251
# ...                    ...                       ...
# 233974                <NA>                      <NA>
# 233975                <NA>                      <NA>
# 233976                <NA>                      <NA>
# 233977                <NA>                      <NA>
# 233978                <NA>                      <NA>
#
#         OMACHT8_NOPELL_NOTFIRSTTIME                  ADDR
# 0                                78  4900 Meridian Street
# 1                                78  4900 Meridian Street
# 2                                78  4900 Meridian Street
# 3                                78  4900 Meridian Street
# 4                                78  4900 Meridian Street
# ...                             ...                   ...
# 233974                         <NA>                  <NA>
# 233975                         <NA>                  <NA>
# 233976                         <NA>                  <NA>
# 233977                         <NA>                  <NA>
# 233978                         <NA>                  <NA>
#
# [233979 rows x 3206 columns]

# %% [markdown]
# We will convert any boolean variables to have a boolean dtype.

# %%
for col in joined_college_scorecard.columns:
    unique_cols = joined_college_scorecard[col].unique()
    if len(unique_cols) <= 3 and 0 in unique_cols and 1 in unique_cols:
        #print(f"Converting {col} to boolean")
        joined_college_scorecard[col] = joined_college_scorecard[col].astype("boolean")

joined_college_scorecard
# Out:
#         UNITID  OPEID6_field_of_study               INSTNM_field_of_study  \
# 0       100654                   1002            Alabama A & M University
# 1       100654                   1002            Alabama A & M University
# 2       100654                   1002            Alabama A & M University
# 3       100654                   1002            Alabama A & M University
# 4       100654                   1002            Alabama A & M University
# ...        ...                    ...                                 ...
# 233974    <NA>                  42640      California Southern University
# 233975    <NA>                  42640      California Southern University
# 233976    <NA>                  42924  Body Wisdom Massage Therapy School
# 233977    <NA>                  42961            Madera Community College
# 233978    <NA>                  42961            Madera Community College
#
#        CONTROL_field_of_study  MAIN_field_of_study  CIPCODE  \
# 0                      Public                 True      100
# 1                      Public                 True      101
# 2                      Public                 True      109
# 3                      Public                 True      110
# 4                      Public                 True      110
# ...                       ...                  ...      ...
# 233974    Private, for-profit                 True     4228
# 233975    Private, for-profit                 True     5138
# 233976    Private, for-profit                 True     5135
# 233977                 Public                 True     2401
# 233978                 Public                 True     5138
#
#                                                   CIPDESC  CREDLEV  \
# 0                                   Agriculture, General.        3
# 1                   Agricultural Business and Management.        3
# 2                                        Animal Sciences.        3
# 3                            Food Science and Technology.        3
# 4                            Food Science and Technology.        5
# ...                                                   ...      ...
# 233974       Clinical, Counseling and Applied Psychology.        7
# 233975  Registered Nursing, Nursing Administration, Nu...        3
# 233976  Somatic Bodywork and Related Therapeutic Servi...        1
# 233977  Liberal Arts and Sciences, General Studies and...        2
# 233978  Registered Nursing, Nursing Administration, Nu...        2
#
#                                     CREDDESC  IPEDSCOUNT1  ...  \
# 0                          Bachelor's Degree         <NA>  ...
# 1                          Bachelor's Degree         <NA>  ...
# 2                          Bachelor's Degree            6  ...
# 3                          Bachelor's Degree            7  ...
# 4                            Master's Degree            8  ...
# ...                                      ...          ...  ...
# 233974             First Professional Degree         <NA>  ...
# 233975                     Bachelor's Degree         <NA>  ...
# 233976  Undergraduate Certificate or Diploma         <NA>  ...
# 233977                    Associate's Degree         <NA>  ...
# 233978                    Associate's Degree         <NA>  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 0                         0.3187                    0.2709
# 1                         0.3187                    0.2709
# 2                         0.3187                    0.2709
# 3                         0.3187                    0.2709
# 4                         0.3187                    0.2709
# ...                          ...                       ...
# 233974                      <NA>                      <NA>
# 233975                      <NA>                      <NA>
# 233976                      <NA>                      <NA>
# 233977                      <NA>                      <NA>
# 233978                      <NA>                      <NA>
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 0                            0.0128                       0.2949
# 1                            0.0128                       0.2949
# 2                            0.0128                       0.2949
# 3                            0.0128                       0.2949
# 4                            0.0128                       0.2949
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 0                            0.4744                       0.2179
# 1                            0.4744                       0.2179
# 2                            0.4744                       0.2179
# 3                            0.4744                       0.2179
# 4                            0.4744                       0.2179
# ...                             ...                          ...
# 233974                         <NA>                         <NA>
# 233975                         <NA>                         <NA>
# 233976                         <NA>                         <NA>
# 233977                         <NA>                         <NA>
# 233978                         <NA>                         <NA>
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 0                      329                       251
# 1                      329                       251
# 2                      329                       251
# 3                      329                       251
# 4                      329                       251
# ...                    ...                       ...
# 233974                <NA>                      <NA>
# 233975                <NA>                      <NA>
# 233976                <NA>                      <NA>
# 233977                <NA>                      <NA>
# 233978                <NA>                      <NA>
#
#         OMACHT8_NOPELL_NOTFIRSTTIME                  ADDR
# 0                                78  4900 Meridian Street
# 1                                78  4900 Meridian Street
# 2                                78  4900 Meridian Street
# 3                                78  4900 Meridian Street
# 4                                78  4900 Meridian Street
# ...                             ...                   ...
# 233974                         <NA>                  <NA>
# 233975                         <NA>                  <NA>
# 233976                         <NA>                  <NA>
# 233977                         <NA>                  <NA>
# 233978                         <NA>                  <NA>
#
# [233979 rows x 3206 columns]

# %% [markdown]
# We will pull out the data from MSOE so it can be used for testing later without target leakage.

# %%
if "msoe_data" not in globals():
    msoe_data = joined_college_scorecard[
        joined_college_scorecard["INSTNM_field_of_study"] == "Milwaukee School of Engineering"]
joined_college_scorecard.drop(index=joined_college_scorecard[
    joined_college_scorecard["INSTNM_field_of_study"] == "Milwaukee School of Engineering"].index,
                              inplace=True)
msoe_data
# Out:
#         UNITID  OPEID6_field_of_study            INSTNM_field_of_study  \
# 192794  239318                   3868  Milwaukee School of Engineering
# 192795  239318                   3868  Milwaukee School of Engineering
# 192796  239318                   3868  Milwaukee School of Engineering
# 192797  239318                   3868  Milwaukee School of Engineering
# 192798  239318                   3868  Milwaukee School of Engineering
# 192799  239318                   3868  Milwaukee School of Engineering
# 192800  239318                   3868  Milwaukee School of Engineering
# 192801  239318                   3868  Milwaukee School of Engineering
# 192802  239318                   3868  Milwaukee School of Engineering
# 192803  239318                   3868  Milwaukee School of Engineering
# 192804  239318                   3868  Milwaukee School of Engineering
# 192805  239318                   3868  Milwaukee School of Engineering
# 192806  239318                   3868  Milwaukee School of Engineering
# 192807  239318                   3868  Milwaukee School of Engineering
# 192808  239318                   3868  Milwaukee School of Engineering
# 192809  239318                   3868  Milwaukee School of Engineering
# 192810  239318                   3868  Milwaukee School of Engineering
# 192811  239318                   3868  Milwaukee School of Engineering
# 192812  239318                   3868  Milwaukee School of Engineering
# 192813  239318                   3868  Milwaukee School of Engineering
# 192814  239318                   3868  Milwaukee School of Engineering
# 192815  239318                   3868  Milwaukee School of Engineering
# 192816  239318                   3868  Milwaukee School of Engineering
# 192817  239318                   3868  Milwaukee School of Engineering
# 192818  239318                   3868  Milwaukee School of Engineering
# 192819  239318                   3868  Milwaukee School of Engineering
# 192820  239318                   3868  Milwaukee School of Engineering
# 192821  239318                   3868  Milwaukee School of Engineering
# 192822  239318                   3868  Milwaukee School of Engineering
# 192823  239318                   3868  Milwaukee School of Engineering
# 192824  239318                   3868  Milwaukee School of Engineering
# 192825  239318                   3868  Milwaukee School of Engineering
# 192826  239318                   3868  Milwaukee School of Engineering
# 192827  239318                   3868  Milwaukee School of Engineering
# 192828  239318                   3868  Milwaukee School of Engineering
# 192829  239318                   3868  Milwaukee School of Engineering
# 192830  239318                   3868  Milwaukee School of Engineering
# 192831  239318                   3868  Milwaukee School of Engineering
# 192832  239318                   3868  Milwaukee School of Engineering
# 192833  239318                   3868  Milwaukee School of Engineering
#
#        CONTROL_field_of_study  MAIN_field_of_study  CIPCODE  \
# 192794     Private, nonprofit                 True      909
# 192795     Private, nonprofit                 True     1107
# 192796     Private, nonprofit                 True     1108
# 192797     Private, nonprofit                 True     1401
# 192798     Private, nonprofit                 True     1401
# 192799     Private, nonprofit                 True     1404
# 192800     Private, nonprofit                 True     1404
# 192801     Private, nonprofit                 True     1405
# 192802     Private, nonprofit                 True     1407
# 192803     Private, nonprofit                 True     1408
# 192804     Private, nonprofit                 True     1408
# 192805     Private, nonprofit                 True     1409
# 192806     Private, nonprofit                 True     1410
# 192807     Private, nonprofit                 True     1414
# 192808     Private, nonprofit                 True     1419
# 192809     Private, nonprofit                 True     1435
# 192810     Private, nonprofit                 True     1437
# 192811     Private, nonprofit                 True     1503
# 192812     Private, nonprofit                 True     1508
# 192813     Private, nonprofit                 True     2609
# 192814     Private, nonprofit                 True     3031
# 192815     Private, nonprofit                 True     5109
# 192816     Private, nonprofit                 True     5127
# 192817     Private, nonprofit                 True     5138
# 192818     Private, nonprofit                 True     5138
# 192819     Private, nonprofit                 True     5138
# 192820     Private, nonprofit                 True     5201
# 192821     Private, nonprofit                 True     5202
# 192822     Private, nonprofit                 True     5202
# 192823     Private, nonprofit                 True     5202
# 192824     Private, nonprofit                 True     5207
# 192825     Private, nonprofit                 True     5211
# 192826     Private, nonprofit                 True     5211
# 192827     Private, nonprofit                 True     5211
# 192828     Private, nonprofit                 True     5212
# 192829     Private, nonprofit                 True     5212
# 192830     Private, nonprofit                 True     5213
# 192831     Private, nonprofit                 True     5213
# 192832     Private, nonprofit                 True     5220
# 192833     Private, nonprofit                 True     5220
#
#                                                   CIPDESC  CREDLEV  \
# 192794  Public Relations, Advertising, and Applied Com...        3
# 192795                                  Computer Science.        3
# 192796          Computer Software and Media Applications.        1
# 192797                              Engineering, General.        3
# 192798                              Engineering, General.        5
# 192799                         Architectural Engineering.        3
# 192800                         Architectural Engineering.        5
# 192801                    Biomedical/Medical Engineering.        3
# 192802                              Chemical Engineering.        3
# 192803                                 Civil Engineering.        3
# 192804                                 Civil Engineering.        5
# 192805                              Computer Engineering.        3
# 192806  Electrical, Electronics and Communications Eng...        3
# 192807    Environmental/Environmental Health Engineering.        5
# 192808                            Mechanical Engineering.        3
# 192809                            Industrial Engineering.        3
# 192810                               Operations Research.        3
# 192811   Electrical Engineering Technologies/Technicians.        3
# 192812  Mechanical Engineering Related Technologies/Te...        3
# 192813        Physiology, Pathology and Related Sciences.        5
# 192814                        Human Computer Interaction.        3
# 192815  Allied Health Diagnostic, Intervention, and Tr...        5
# 192816              Medical Illustration and Informatics.        5
# 192817  Registered Nursing, Nursing Administration, Nu...        3
# 192818  Registered Nursing, Nursing Administration, Nu...        5
# 192819  Registered Nursing, Nursing Administration, Nu...        8
# 192820                        Business/Commerce, General.        3
# 192821  Business Administration, Management and Operat...        3
# 192822  Business Administration, Management and Operat...        5
# 192823  Business Administration, Management and Operat...        8
# 192824     Entrepreneurial and Small Business Operations.        8
# 192825                            International Business.        3
# 192826                            International Business.        5
# 192827                            International Business.        8
# 192828       Management Information Systems and Services.        3
# 192829       Management Information Systems and Services.        8
# 192830      Management Sciences and Quantitative Methods.        3
# 192831      Management Sciences and Quantitative Methods.        8
# 192832                           Construction Management.        3
# 192833                           Construction Management.        5
#
#                                     CREDDESC  IPEDSCOUNT1  ...  \
# 192794                     Bachelor's Degree            1  ...
# 192795                     Bachelor's Degree         <NA>  ...
# 192796  Undergraduate Certificate or Diploma            1  ...
# 192797                     Bachelor's Degree            2  ...
# 192798                       Master's Degree            9  ...
# 192799                     Bachelor's Degree           23  ...
# 192800                       Master's Degree            8  ...
# 192801                     Bachelor's Degree           44  ...
# 192802                     Bachelor's Degree           18  ...
# 192803                     Bachelor's Degree           16  ...
# 192804                       Master's Degree           12  ...
# 192805                     Bachelor's Degree           80  ...
# 192806                     Bachelor's Degree           87  ...
# 192807                       Master's Degree            0  ...
# 192808                     Bachelor's Degree          122  ...
# 192809                     Bachelor's Degree           39  ...
# 192810                     Bachelor's Degree            0  ...
# 192811                     Bachelor's Degree            0  ...
# 192812                     Bachelor's Degree            0  ...
# 192813                       Master's Degree            0  ...
# 192814                     Bachelor's Degree            1  ...
# 192815                       Master's Degree            7  ...
# 192816                       Master's Degree            1  ...
# 192817                     Bachelor's Degree           68  ...
# 192818                       Master's Degree            4  ...
# 192819     Graduate/Professional Certificate         <NA>  ...
# 192820                     Bachelor's Degree            0  ...
# 192821                     Bachelor's Degree           18  ...
# 192822                       Master's Degree           76  ...
# 192823     Graduate/Professional Certificate           11  ...
# 192824     Graduate/Professional Certificate            5  ...
# 192825                     Bachelor's Degree            4  ...
# 192826                       Master's Degree            0  ...
# 192827     Graduate/Professional Certificate            0  ...
# 192828                     Bachelor's Degree            5  ...
# 192829     Graduate/Professional Certificate            3  ...
# 192830                     Bachelor's Degree            7  ...
# 192831     Graduate/Professional Certificate         <NA>  ...
# 192832                     Bachelor's Degree           14  ...
# 192833                       Master's Degree            1  ...
#
#         OMAWDP8_NOPELL_FIRSTTIME  OMENRUP_NOPELL_FIRSTTIME  \
# 192794                    0.6599                    0.1059
# 192795                    0.6599                    0.1059
# 192796                    0.6599                    0.1059
# 192797                    0.6599                    0.1059
# 192798                    0.6599                    0.1059
# 192799                    0.6599                    0.1059
# 192800                    0.6599                    0.1059
# 192801                    0.6599                    0.1059
# 192802                    0.6599                    0.1059
# 192803                    0.6599                    0.1059
# 192804                    0.6599                    0.1059
# 192805                    0.6599                    0.1059
# 192806                    0.6599                    0.1059
# 192807                    0.6599                    0.1059
# 192808                    0.6599                    0.1059
# 192809                    0.6599                    0.1059
# 192810                    0.6599                    0.1059
# 192811                    0.6599                    0.1059
# 192812                    0.6599                    0.1059
# 192813                    0.6599                    0.1059
# 192814                    0.6599                    0.1059
# 192815                    0.6599                    0.1059
# 192816                    0.6599                    0.1059
# 192817                    0.6599                    0.1059
# 192818                    0.6599                    0.1059
# 192819                    0.6599                    0.1059
# 192820                    0.6599                    0.1059
# 192821                    0.6599                    0.1059
# 192822                    0.6599                    0.1059
# 192823                    0.6599                    0.1059
# 192824                    0.6599                    0.1059
# 192825                    0.6599                    0.1059
# 192826                    0.6599                    0.1059
# 192827                    0.6599                    0.1059
# 192828                    0.6599                    0.1059
# 192829                    0.6599                    0.1059
# 192830                    0.6599                    0.1059
# 192831                    0.6599                    0.1059
# 192832                    0.6599                    0.1059
# 192833                    0.6599                    0.1059
#
#         OMENRYP_NOPELL_NOTFIRSTTIME  OMENRAP_NOPELL_NOTFIRSTTIME  \
# 192794                          0.0                        0.097
# 192795                          0.0                        0.097
# 192796                          0.0                        0.097
# 192797                          0.0                        0.097
# 192798                          0.0                        0.097
# 192799                          0.0                        0.097
# 192800                          0.0                        0.097
# 192801                          0.0                        0.097
# 192802                          0.0                        0.097
# 192803                          0.0                        0.097
# 192804                          0.0                        0.097
# 192805                          0.0                        0.097
# 192806                          0.0                        0.097
# 192807                          0.0                        0.097
# 192808                          0.0                        0.097
# 192809                          0.0                        0.097
# 192810                          0.0                        0.097
# 192811                          0.0                        0.097
# 192812                          0.0                        0.097
# 192813                          0.0                        0.097
# 192814                          0.0                        0.097
# 192815                          0.0                        0.097
# 192816                          0.0                        0.097
# 192817                          0.0                        0.097
# 192818                          0.0                        0.097
# 192819                          0.0                        0.097
# 192820                          0.0                        0.097
# 192821                          0.0                        0.097
# 192822                          0.0                        0.097
# 192823                          0.0                        0.097
# 192824                          0.0                        0.097
# 192825                          0.0                        0.097
# 192826                          0.0                        0.097
# 192827                          0.0                        0.097
# 192828                          0.0                        0.097
# 192829                          0.0                        0.097
# 192830                          0.0                        0.097
# 192831                          0.0                        0.097
# 192832                          0.0                        0.097
# 192833                          0.0                        0.097
#
#         OMAWDP8_NOPELL_NOTFIRSTTIME  OMENRUP_NOPELL_NOTFIRSTTIME  \
# 192794                       0.6667                       0.2364
# 192795                       0.6667                       0.2364
# 192796                       0.6667                       0.2364
# 192797                       0.6667                       0.2364
# 192798                       0.6667                       0.2364
# 192799                       0.6667                       0.2364
# 192800                       0.6667                       0.2364
# 192801                       0.6667                       0.2364
# 192802                       0.6667                       0.2364
# 192803                       0.6667                       0.2364
# 192804                       0.6667                       0.2364
# 192805                       0.6667                       0.2364
# 192806                       0.6667                       0.2364
# 192807                       0.6667                       0.2364
# 192808                       0.6667                       0.2364
# 192809                       0.6667                       0.2364
# 192810                       0.6667                       0.2364
# 192811                       0.6667                       0.2364
# 192812                       0.6667                       0.2364
# 192813                       0.6667                       0.2364
# 192814                       0.6667                       0.2364
# 192815                       0.6667                       0.2364
# 192816                       0.6667                       0.2364
# 192817                       0.6667                       0.2364
# 192818                       0.6667                       0.2364
# 192819                       0.6667                       0.2364
# 192820                       0.6667                       0.2364
# 192821                       0.6667                       0.2364
# 192822                       0.6667                       0.2364
# 192823                       0.6667                       0.2364
# 192824                       0.6667                       0.2364
# 192825                       0.6667                       0.2364
# 192826                       0.6667                       0.2364
# 192827                       0.6667                       0.2364
# 192828                       0.6667                       0.2364
# 192829                       0.6667                       0.2364
# 192830                       0.6667                       0.2364
# 192831                       0.6667                       0.2364
# 192832                       0.6667                       0.2364
# 192833                       0.6667                       0.2364
#
#         OMACHT8_NOPELL_ALL  OMACHT8_NOPELL_FIRSTTIME  \
# 192794                 609                       444
# 192795                 609                       444
# 192796                 609                       444
# 192797                 609                       444
# 192798                 609                       444
# 192799                 609                       444
# 192800                 609                       444
# 192801                 609                       444
# 192802                 609                       444
# 192803                 609                       444
# 192804                 609                       444
# 192805                 609                       444
# 192806                 609                       444
# 192807                 609                       444
# 192808                 609                       444
# 192809                 609                       444
# 192810                 609                       444
# 192811                 609                       444
# 192812                 609                       444
# 192813                 609                       444
# 192814                 609                       444
# 192815                 609                       444
# 192816                 609                       444
# 192817                 609                       444
# 192818                 609                       444
# 192819                 609                       444
# 192820                 609                       444
# 192821                 609                       444
# 192822                 609                       444
# 192823                 609                       444
# 192824                 609                       444
# 192825                 609                       444
# 192826                 609                       444
# 192827                 609                       444
# 192828                 609                       444
# 192829                 609                       444
# 192830                 609                       444
# 192831                 609                       444
# 192832                 609                       444
# 192833                 609                       444
#
#         OMACHT8_NOPELL_NOTFIRSTTIME             ADDR
# 192794                          165  1025 N Broadway
# 192795                          165  1025 N Broadway
# 192796                          165  1025 N Broadway
# 192797                          165  1025 N Broadway
# 192798                          165  1025 N Broadway
# 192799                          165  1025 N Broadway
# 192800                          165  1025 N Broadway
# 192801                          165  1025 N Broadway
# 192802                          165  1025 N Broadway
# 192803                          165  1025 N Broadway
# 192804                          165  1025 N Broadway
# 192805                          165  1025 N Broadway
# 192806                          165  1025 N Broadway
# 192807                          165  1025 N Broadway
# 192808                          165  1025 N Broadway
# 192809                          165  1025 N Broadway
# 192810                          165  1025 N Broadway
# 192811                          165  1025 N Broadway
# 192812                          165  1025 N Broadway
# 192813                          165  1025 N Broadway
# 192814                          165  1025 N Broadway
# 192815                          165  1025 N Broadway
# 192816                          165  1025 N Broadway
# 192817                          165  1025 N Broadway
# 192818                          165  1025 N Broadway
# 192819                          165  1025 N Broadway
# 192820                          165  1025 N Broadway
# 192821                          165  1025 N Broadway
# 192822                          165  1025 N Broadway
# 192823                          165  1025 N Broadway
# 192824                          165  1025 N Broadway
# 192825                          165  1025 N Broadway
# 192826                          165  1025 N Broadway
# 192827                          165  1025 N Broadway
# 192828                          165  1025 N Broadway
# 192829                          165  1025 N Broadway
# 192830                          165  1025 N Broadway
# 192831                          165  1025 N Broadway
# 192832                          165  1025 N Broadway
# 192833                          165  1025 N Broadway
#
# [40 rows x 3206 columns]

# %% [markdown]
# We will also do the same for two neighboring universities.

# %%
if "marquette_data" not in globals():
    marquette_data = joined_college_scorecard[
        joined_college_scorecard["INSTNM_field_of_study"] == "Marquette University"]
joined_college_scorecard.drop(index=joined_college_scorecard[
    joined_college_scorecard["INSTNM_field_of_study"] == "Marquette University"].index,
                              inplace=True)

# %%
if "uwm_data" not in globals():
    uwm_data = joined_college_scorecard[
        joined_college_scorecard["INSTNM_field_of_study"] == "University of Wisconsin-Milwaukee"]
joined_college_scorecard.drop(index=joined_college_scorecard[
    joined_college_scorecard["INSTNM_field_of_study"] == "University of Wisconsin-Milwaukee"].index,
                              inplace=True)

# %% [markdown]
# # Debt Column Key
# The dataset has many columns. This section serves as a key to the different ways debt is recorded in the dataset.
#
# Format: `DEBT_[Disaggregation]_[Loan Type]_[Method]_[Metric]`
# ## Disaggregation
# - MALE: Men only
# - NOTMALE: Women only
# - PELL: People who got Pell grants.
# - NOPELL: People who did not receive Pell grants.
# - ALL: All graduates, no disaggregation
# - STGP: Stafford and Graduate Plus loans
# - PP: Parent Plus loans
# ## Method
# - EVAL: Debts originated only at the specified institution.
# - ANY: Debts originated at any institution attended by graduates.
# ## Metric
# - N: number of grads with loans
# - MDN: Median loan amount dispersed.
# - MEAN: Mean loan amount dispersed.

# %%
pd.DataFrame(joined_college_scorecard[
                 filter(lambda label: "DEBT" in label, joined_college_scorecard.columns)].columns)
# Out:
#                                 0
# 0             DEBT_ALL_STGP_ANY_N
# 1          DEBT_ALL_STGP_ANY_MEAN
# 2           DEBT_ALL_STGP_ANY_MDN
# 3            DEBT_ALL_STGP_EVAL_N
# 4         DEBT_ALL_STGP_EVAL_MEAN
# ..                            ...
# 146     PLUS_DEBT_ALL_STAFFANY_MD
# 147   PLUS_DEBT_INST_NOSTAFFANY_N
# 148  PLUS_DEBT_INST_NOSTAFFANY_MD
# 149    PLUS_DEBT_ALL_NOSTAFFANY_N
# 150   PLUS_DEBT_ALL_NOSTAFFANY_MD
#
# [151 rows x 1 columns]

# %% [markdown]
# # Hypothesis Testing
#
# Before attempting to make a machine learning model, we will check our data to make sure that there is correlations between the various numerical and categorical variables, and the most broad form of student debt recorded.

# %%
pd.DataFrame(joined_college_scorecard.dtypes.unique())
# Out:
#                 0
# 0           Int64
# 1  string[python]
# 2         boolean
# 3         Float64

# %% [markdown]
# Our first test will check for linear relationships between the numerical variables in the dataset and the target debt column we selected.

# %%
numeric_variables = list(filter(lambda
                                    col: not "DEBT" in col and not "BRR" in col and not "CDR" in col and not "LP" in col and not "OPEID" in col and not "UNITID" in col and not "LOAN" in col,
                                joined_college_scorecard.select_dtypes(
                                    include=("Int64", "Float64")).columns))

dat = {}

for column in numeric_variables:
    nonna_subset = joined_college_scorecard[[column, "DEBT_ALL_STGP_ANY_MDN"]].dropna()
    if len(nonna_subset >= 2) and nonna_subset[column].nunique() > 1:
        res = stats.pearsonr(nonna_subset["DEBT_ALL_STGP_ANY_MDN"], nonna_subset[column])
        if res[1] < 0.05:
            dat[column] = {"R": res[0], "p-value": res[1]}

df = pd.DataFrame.from_dict(dat, orient='index')
df.reset_index(inplace=True)
df.rename(columns={'index': 'Column', 'R': 'Statistic'}, inplace=True)
df
# Out:
#                            Column  Statistic        p-value
# 0                         CREDLEV   0.560530   0.000000e+00
# 1                     IPEDSCOUNT1  -0.140444  2.625938e-169
# 2                     IPEDSCOUNT2  -0.129023  4.772835e-140
# 3          EARN_COUNT_NWNE_HI_1YR  -0.016052   1.424259e-03
# 4          EARN_CNTOVER150_HI_1YR   0.116071   1.032957e-90
# ...                           ...        ...            ...
# 1744  OMAWDP8_NOPELL_NOTFIRSTTIME   0.068138   5.791360e-38
# 1745  OMENRUP_NOPELL_NOTFIRSTTIME  -0.027757   1.588131e-07
# 1746           OMACHT8_NOPELL_ALL  -0.107071   3.972342e-92
# 1747     OMACHT8_NOPELL_FIRSTTIME  -0.118420  2.110588e-112
# 1748  OMACHT8_NOPELL_NOTFIRSTTIME  -0.065370   2.412946e-35
#
# [1749 rows x 3 columns]

# %% [markdown]
# For the categorical variables, we will use ANOVA to compare them with debt.

# %%
# Identify categorical variables
categorical_vars = joined_college_scorecard.select_dtypes(include=['category', 'boolean']).columns

# Drop missing values from relevant columns
joined_college_scorecard_clean = joined_college_scorecard.dropna(
    subset=['DEBT_ALL_STGP_ANY_MDN'] + list(categorical_vars))

# Initialize an empty list to store p-values
p_values = []

# Perform Kruskal-Wallis test for each categorical variable
for var in categorical_vars:
    unique_values = joined_college_scorecard_clean[var].unique()
    if len(unique_values) < 2:
        # Skip variables with only one unique value
        continue

    samples_by_group = []
    for val in unique_values:
        mask = joined_college_scorecard_clean[var] == val
        samples_by_group.append(joined_college_scorecard_clean['DEBT_ALL_STGP_ANY_MDN'][mask])

    stat, p = kruskal(*samples_by_group)
    if p < 0.05:
        p_values.append((var, p))

# Convert the list of tuples to a DataFrame for better visualization
p_values_df = pd.DataFrame(p_values, columns=['Variable', 'p-value'])

p_values_df
# Out:
#         Variable        p-value
# 0           HCM2   4.146386e-20
# 1           HBCU  9.143728e-218
# 2          ANNHI   5.869762e-03
# 3        AANAPII   2.478460e-60
# 4            HSI  4.560183e-222
# 5          NANTI   1.397334e-08
# 6        MENONLY   6.055642e-07
# 7      WOMENONLY   1.732759e-19
# 8     CIP01CERT4   2.726374e-13
# 9     CIP04CERT1   7.487358e-06
# 10    CIP04CERT2   1.895566e-05
# 11    CIP05CERT4   1.604488e-07
# 12    CIP12CERT4   3.338861e-66
# 13    CIP14CERT4   1.638429e-05
# 14    CIP23CERT4   1.680649e-04
# 15    CIP25CERT4   8.525719e-07
# 16    CIP30CERT4   1.062604e-02
# 17    CIP42CERT4   1.252491e-03
# 18    CIP43CERT4   1.555471e-05
# 19    CIP46CERT4   8.381871e-70
# 20    CIP47CERT4  5.382016e-198
# 21    CIP48CERT4   6.390711e-66
# 22    CIP48BACHL   2.109737e-04
# 23    CIP49CERT4   1.212385e-04
# 24  DISTANCEONLY   5.524966e-39
# 25      CURROPER   5.949274e-03
# 26   DOLPROVIDER  1.692967e-161

# %% [markdown]
# # Machine Learning

# %% [markdown]
# This attempts to train a model to see if random forest will work.

# %%
temp_subset = joined_college_scorecard.dropna(subset=["DEBT_ALL_STGP_ANY_MDN"])
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    temp_subset[[*numeric_variables, *categorical_vars]], temp_subset["DEBT_ALL_STGP_ANY_MDN"],
    random_state=42)

model = ensemble.RandomForestRegressor(n_jobs=-1, oob_score=True, random_state=42)
model.fit(X_train, y_train)
model.score(X_test, y_test)
# Out:
# 0.6613164386754449

# %%
feature_importances = pd.Series(model.feature_importances_,
                                index=[*numeric_variables, *categorical_vars]).sort_values(
    ascending=False)
feature_importances
# Out:
# CREDLEV                            0.302561
# AGE_ENTRY                          0.114891
# HI_INC_RPY_1YR_RT                  0.047421
# TUITIONFEE_IN                      0.036420
# EARN_NOMALE_WNE_MDN_1YR            0.036115
#                                      ...
# POOLYRS200                         0.000000
# FEMALE_UNKN_4YR_TRANS_YR6_RT       0.000000
# CIP16CERT2                         0.000000
# FEMALE_UNKN_ORIG_YR4_RT            0.000000
# NOT1STGEN_ENRL_2YR_TRANS_YR6_RT    0.000000
# Length: 1935, dtype: float64

# %% [markdown]
# Attempts prediction with data from MSOE. Expected values are at https://collegescorecard.ed.gov/school/?239318-Milwaukee-School-of-Engineering

# %%
msoe_predictions = model.predict(msoe_data[[*numeric_variables, *categorical_vars]])
msoe_predictions
# Out:
# array([27000., 40375., 15000., 27000., 27000., 27000., 28000., 27000.,
#        27000., 27000., 27000., 31000., 27639., 27000., 27639., 26054.,
#        30697., 27000., 27000., 28000., 30697., 27000., 27000., 27639.,
#        27000., 28000., 30697., 27000., 19338., 28000., 28000., 27250.,
#        27250., 28000., 27000., 28000., 27250., 28000., 27250., 27250.])

# %% [markdown]
# Attempts prediction with data from Marquette. Expected values are at https://collegescorecard.ed.gov/school/?239105-Marquette-University

# %%
marquette_predictions = model.predict(marquette_data[[*numeric_variables, *categorical_vars]])
marquette_predictions
# Out:
# array([25028., 25028., 25028., 26884., 25074., 27000., 26884., 26000.,
#        23250., 22903., 26694., 25074., 22903., 22903., 22903., 25028.,
#        20000., 25074., 20000., 25074., 26000., 22250., 26664., 22250.,
#        28818., 26843., 25074., 25074., 27334., 25074., 25074., 28000.,
#        26664., 25074., 25074., 28818., 28818., 22250., 27334., 22250.,
#        22250., 27000., 22250., 25074., 28818., 23250., 28818., 20792.,
#        22250., 28818., 25074., 25074., 26137., 28818., 26000., 25074.,
#        25074., 27000., 27000., 27000., 25074., 22250., 26949., 27000.,
#        27000., 22250., 22250., 27000., 22250., 25074., 27000., 22250.,
#        22250., 22250., 22250., 27000., 22250., 27000., 25074., 22250.,
#        25074., 28281., 22250., 22250., 27000., 22250., 27000., 27000.,
#        27000., 27000., 27000., 27000., 26000., 22250., 22250., 22250.,
#        27000., 27000., 26500., 27000., 27000., 27000., 27000., 22250.,
#        27000., 22250., 27000., 22250., 24250., 27000., 27000., 27000.,
#        27000., 20250., 20125., 20250., 20250., 20250., 27000., 27000.,
#        20250., 23250., 27000., 20250., 20250., 27000., 20250., 20250.,
#        27000., 27000., 27000., 20250., 27000., 27000., 27000., 27000.,
#        20125., 27000., 27000., 27000., 24495., 20250., 27000., 27000.,
#        27000., 27000., 27000., 27000., 26000., 27000., 27000., 19323.,
#        19323., 27000., 31741., 27000., 29198., 27000., 27000.])

# %% [markdown]
# Attempts prediction with data from UWM. Expected values are at https://collegescorecard.ed.gov/school/?240453-University-of-Wisconsin-Milwaukee

# %%
uwm_predictions = model.predict(uwm_data[[*numeric_variables, *categorical_vars]])
uwm_predictions
# Out:
# array([19125., 22746., 25000., 20500., 22641., 22959., 20500., 22673.,
#        22527., 19966., 22527., 22527., 22673., 20500., 22673., 26500.,
#        20500., 20500., 20500., 33518., 22527., 20500., 20500., 22527.,
#        22527., 22527., 22527., 22959., 20500., 20500., 17922., 25000.,
#        25000., 17922., 23667., 24201., 31000., 22527., 22527., 27000.,
#        23405., 24701., 25000., 20500., 19966., 17922., 20500., 24617.,
#        20500., 20500., 27816., 20500., 17922., 23667., 20500., 22527.,
#        25499., 22527., 28537., 27000., 19966., 17922., 27000., 22527.,
#        20500., 27000., 25499., 20500., 24617., 20500., 20500., 20500.,
#        23667., 17922., 20500., 20500., 24875., 20500., 17922., 22527.,
#        22527., 20500., 17032., 19500., 22527., 22851., 17032., 26642.,
#        12250., 24938., 22527., 20500., 24250., 22527., 17032., 26000.,
#        25000., 20500., 17032., 23183., 20500., 22527., 22527., 20500.,
#        22527., 20500., 20500., 17032., 22527., 20500., 22527., 17032.,
#        20500., 20500., 22673., 23667., 25000., 24875., 17032., 22527.,
#        20500., 20500., 18896., 20500., 27816., 20500., 20500., 17999.,
#        14133., 20500., 18896., 20500., 20500., 17999., 20500., 20500.,
#        20500., 26000., 20500., 20500., 20500., 20500., 20500., 17999.,
#        24250., 20500., 20500., 24750., 20500., 26000., 17999., 24062.,
#        14133., 22673., 26000., 24075., 25000., 24075., 27000., 26000.,
#        24000., 20500., 26000., 20500., 20500., 20500., 24075., 20500.,
#        24750., 26000., 20500., 20500., 20500., 20500., 20500., 22641.,
#        20500., 20500., 24075., 27000., 20500., 20500., 24075., 20500.,
#        20500., 20500., 25000., 24408., 24750., 20500., 20500., 14133.,
#        20500., 25914., 25105., 26000., 22673., 25750., 20500., 24075.,
#        25750., 22851., 26000., 26000., 27000., 26000., 26000., 29750.,
#        29875., 24075., 20500., 20500., 23419., 20500., 23168., 24075.,
#        24075., 27000., 20500., 23168., 22673., 25250., 27000., 23168.,
#        20500., 22673., 23168., 20500., 20500., 24075., 24250., 22959.,
#        25000., 27000., 20500., 20500., 23168., 22673., 23168., 20500.,
#        24075., 21500., 23250., 21500., 23250., 20348., 22673., 23250.,
#        21500., 23250., 22000., 24500., 21125., 23250., 15000., 23250.,
#        23250., 21125., 22673., 23250., 23250., 23250., 23250., 22002.,
#        23250., 23250.])

# %% [markdown]
# We finish off by exporting the model to a pickle.

# %%
import pickle

with open("data/model.pickle", "wb") as f:
    pickle.dump(model, f, pickle.HIGHEST_PROTOCOL)
